# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/yolov5l-pt/yolov5l.pt
# /kaggle/input/transformer/yolov5l_fusion_transformerx3_vedai.yaml
# /kaggle/input/vedai-dataset/dataset/ir/ir_valid.cache
# /kaggle/input/vedai-dataset/dataset/ir/ir_train.cache
# /kaggle/input/vedai-dataset/dataset/ir/ir_valid.txt
# /kaggle/input/vedai-dataset/dataset/ir/ir_train.txt
# /kaggle/input/vedai-dataset/dataset/ir/labels/00000127_ir_png.rf.646685420c6949b30d4142498566eebf.txt
# /kaggle/input/vedai-dataset/dataset/ir/labels/00000886_ir_png.rf.eaa54b281610c116e5fb00918d80b01b.txt
# /kaggle/input/vedai-dataset/dataset/ir/labels/00000500_ir_png.rf.c2e5b326a192ddb23af7d2c2cea470cf.txt
# /kaggle/input/vedai-dataset/dataset/ir/labels/00000062_ir_png.rf.1ceb73d50f777beeff1bff8031ce1824.txt
# /kaggle/input/vedai-dataset/dataset/ir/labels/00001056_ir_png.rf.bcb01bf3d5a6638d8d6490ed281fd75b.txt
# /kaggle/input/vedai-dataset/dataset/ir/labels/00000953_ir_png.rf.855f87f40264afb7ba258d9a8ccaafec.txt
# ...

# %%
# !git clone https://github.com/Forbbi/multispectral-object-detection.git
# Out:
# Cloning into 'multispectral-object-detection'...
# remote: Enumerating objects: 358, done.
# remote: Counting objects: 100% (175/175), done.
# remote: Compressing objects: 100% (93/93), done.
# remote: Total 358 (delta 131), reused 81 (delta 81), pack-reused 183 (from 1)
# Receiving objects: 100% (358/358), 41.57 MiB | 35.92 MiB/s, done.
# Resolving deltas: 100% (161/161), done.

# %%
# prompt: Torch version: 2.4.1+cu121
# Torchvision version: 0.19.1+cu121
# Torchaudio version: 2.4.1+cu121
# give me commnad to install this

# !pip install torch==2.4.1+cu121 torchvision==0.19.1+cu121 torchaudio==2.4.1+cu121 --extra-index-url https://download.pytorch.org/whl/cu121
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu121
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 798.9/798.9 MB 2.0 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 88.2 MB/s eta 0:00:00:00:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 84.2 MB/s eta 0:00:00:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 60.6 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 43.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 81.7 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 4.0 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 13.5 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 28.6 MB/s eta 0:00:0000:0100:01
# ...

# %%
# %cd /kaggle/working/multispectral-object-detection
# Out:
# /kaggle/working/multispectral-object-detection

# %%
# !cp -r /kaggle/input/yolov5s/yolov5s.pt /kaggle/working/multispectral-object-detection

# %%
# !rm -r /kaggle/working/multispectral-object-detection/dataset/color/color_valid.cache

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 427.8/427.8 kB 8.1 MB/s eta 0:00:00ta 0:00:01
# ...

# %%
# !pip uninstall wandb -y
# Out:
# Found existing installation: wandb 0.18.3
# Uninstalling wandb-0.18.3:
#   Successfully uninstalled wandb-0.18.3

# %%
# !python train.py --weights yolov5s.pt --cfg /kaggle/working/multispectral-object-detection/models/transformer/yolov5s_fusion_transformerx3_vedai.yaml --data /kaggle/working/multispectral-object-detection/data/multispectral/vedai_color_2.yaml --epochs 50 --batch-size 10
# Out:
# /kaggle/working/multispectral-object-detection/train.py:498: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
# !python test.py --weights /kaggle/working/multispectral-object-detection/runs/train/exp5/weights/best.pt --data /kaggle/working/multispectral-object-detection/data/multispectral/vedai_color_2.yaml --batch-size 10
# Out:
# Namespace(weights=['/kaggle/working/multispectral-object-detection/runs/train/exp5/weights/best.pt'], data='/kaggle/working/multispectral-object-detection/data/multispectral/vedai_color_2.yaml', batch_size=10, img_size=640, conf_thres=0.001, iou_thres=0.5, task='val', device='', single_cls=False, augment=False, verbose=False, save_txt=True, save_hybrid=False, save_conf=True, save_json=False, project='runs/test', name='exp', exist_ok=False)
# /kaggle/working/multispectral-object-detection/data/multispectral/vedai_color_2.yaml
# ...

# %%
import shutil

# Define the source and destination file paths
source_file_path = '/kaggle/input/yolov5l-pt/yolov5l.pt'
destination_file_path = '/kaggle/working/multispectral-object-detection/yolov5s.pt'

# Copy the content from source to destination
shutil.copy(source_file_path, destination_file_path)

print(f'Copied content from {source_file_path} to {destination_file_path}')
# Out:
# Copied content from /kaggle/input/yolov5l-pt/yolov5l.pt to /kaggle/working/multispectral-object-detection/yolov5s.pt
